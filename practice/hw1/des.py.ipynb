# %%
pc1 = [56, 48, 40, 32, 24, 16,  8,
0, 57, 49, 41, 33, 25, 17,
9,  1, 58, 50, 42, 34, 26,
18, 10,  2, 59, 51, 43, 35,
62, 54, 46, 38, 30, 22, 14,
6, 61, 53, 45, 37, 29, 21,
13,  5, 60, 52, 44, 36, 28,
20, 12,  4, 27, 19, 11,  3
]

pc2 = [
13, 16, 10, 23,  0,  4,
2, 27, 14,  5, 20,  9,
22, 18, 11,  3, 25,  7,
15,  6, 26, 19, 12,  1,
40, 51, 30, 36, 46, 54,
29, 39, 50, 44, 32, 47,
43, 48, 38, 55, 33, 52,
45, 41, 49, 35, 28, 31
]


def permutate(table, block):
    return "".join(list(map(lambda x: block[x], table)))
    
block = "1101001001101011001000110101010101110110010011101011101010001101"

resBlock = permutate(pc1, block)


L = resBlock[:28]
R = resBlock[28:]

print("C0", L)
print("D0", R)
# Out:
# C0 1100000100111011010101100101
# D0 0111011110111000111000101001

# %%
L = list(L)
R = list(R)

# %%
left_rotations = [1, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1]

Kn = [ [0] * 48 ] * 16

i = 0
while i < 16:
    j = 0
    while j < left_rotations[i]:
        L.append(L[0])
        del L[0]
        R.append(R[0])
        del R[0]
        j += 1

    print("=================================================================")
    print("C", i+1,"===>",  "".join(L))
    print("D", i+1, "===>", "".join(R))
    
    Kn[i] = permutate(pc2, L + R)
    
    print("k",i+1,"===>", Kn[i])
    i += 1

L = list(L)
R = list(R)
# Out:
# =================================================================
# C 1 ===> 1000001001110110101011001011
# D 1 ===> 1110111101110001110001010010
# k 1 ===> 111010011011011000011000011001110110101010101110
# =================================================================
# C 2 ===> 0000010011101101010110010111
# D 2 ===> 1101111011100011100010100101
# k 2 ===> 101100010111000010101110000100101110111110000011
# =================================================================
# C 3 ===> 0001001110110101011001011100
# D 3 ===> 0111101110001110001010010111
# k 3 ===> 101100000000011111110000111111100010010100010101
# =================================================================
# C 4 ===> 0100111011010101100101110000
# D 4 ===> 1110111000111000101001011101
# k 4 ===> 110101000101101000110101111010110110001111001010
# =================================================================
# C 5 ===> 0011101101010110010111000001
# D 5 ===> 1011100011100010100101110111
# k 5 ===> 100001111011001101010100011101001111001100001011
# =================================================================
# C 6 ===> 1110110101011001011100000100
# D 6 ===> 1110001110001010010111011110
# k 6 ===> 000011100101011011100111111101100001010001101110
# =================================================================
# C 7 ===> 1011010101100101110000010011
# D 7 ===> 1000111000101001011101111011
# k 7 ===> 111110110101000101101000110011001011101111101010
# =================================================================
# C 8 ===> 1101010110010111000001001110
# D 8 ===> 0011100010100101110111101110
# k 8 ===> 100010001100001111101001001101001111111001111001
# =================================================================
# C 9 ===> 1010101100101110000010011101
# D 9 ===> 0111000101001011101111011100
# k 9 ===> 101111111010000011010010111010100101110001001101
# =================================================================
# C 10 ===> 1010110010111000001001110110
# D 10 ===> 1100010100101110111101110001
# k 10 ===> 001111100100111010001010110010101101001110111110
# =================================================================
# C 11 ===> 1011001011100000100111011010
# D 11 ===> 0001010010111011110111000111
# k 11 ===> 011110100011000100011100100101010101111110101001
# =================================================================
# C 12 ===> 1100101110000010011101101010
# D 12 ===> 0101001011101111011100011100
# k 12 ===> 000011001000110001011101110110100001101001110001
# =================================================================
# C 13 ===> 0010111000001001110110101011
# D 13 ===> 0100101110111101110001110001
# k 13 ===> 010001110110100000111110110100111110101100111100
# =================================================================
# C 14 ===> 1011100000100111011010101100
# D 14 ===> 0010111011110111000111000101
# k 14 ===> 101011101010110110100000001100010011111110011000
# =================================================================
# C 15 ===> 1110000010011101101010110010
# D 15 ===> 1011101111011100011100010100
# k 15 ===> 110110100010111000101011111110010011000000110111
# =================================================================
# C 16 ===> 1100000100111011010101100101
# D 16 ===> 0111011110111000111000101001
# k 16 ===> 001010011000101011100111101110111100001111100101
